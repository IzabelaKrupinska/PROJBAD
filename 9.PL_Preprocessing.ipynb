# %%
import pickle
from tqdm.notebook import tqdm

# %%
# !sudo pip install -U spacy
# !sudo python -m spacy download pl_core_news_md

import pkg_resources,imp
imp.reload(pkg_resources)
# Out:
# Collecting spacy
#   Downloading https://files.pythonhosted.org/packages/c5/5d/20f8252a9dfe7057721136d83cecb1ca1e0936b21fd7a0a4889d1d6650a8/spacy-3.0.1-cp36-cp36m-manylinux2014_x86_64.whl (12.8MB)
#      |████████████████████████████████| 12.8MB 332kB/s
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (20.9)
# Requirement already satisfied, skipping upgrade: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.8.2)
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from spacy) (3.7.4.3)
# Requirement already satisfied, skipping upgrade: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (3.0.5)
# Collecting typer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/90/34/d138832f6945432c638f32137e6c79a3b682f06a63c488dcfaca6b166c64/typer-0.3.2-py3-none-any.whl
# Collecting pathy
#   Downloading https://files.pythonhosted.org/packages/b0/e0/42a9c6fc14882733d5eb367c29873c41a824a51c467395660a13a940b043/pathy-0.3.5-py3-none-any.whl
# Collecting spacy-legacy<3.1.0,>=3.0.0
#   Downloading https://files.pythonhosted.org/packages/65/d5/6c58fc97f3098775e46d8202bf248752e626a8096a0ae9d76aa7c485a09c/spacy_legacy-3.0.1-py2.py3-none-any.whl
# Collecting pydantic<1.8.0,>=1.7.1
#   Downloading https://files.pythonhosted.org/packages/52/ea/fae9f69b6e56407961318e8c73e203097a97c7bd71b30bf1b4f5eb448f28/pydantic-1.7.3-cp36-cp36m-manylinux2014_x86_64.whl (9.2MB)
#      |████████████████████████████████| 9.2MB 52.7MB/s
# Requirement already satisfied, skipping upgrade: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied, skipping upgrade: jinja2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.11.3)
# Collecting thinc<8.1.0,>=8.0.0
#   Downloading https://files.pythonhosted.org/packages/94/c5/214cc68f99c33aa7071d20398dbdf44da92077a86bed43cddd391d4efe26/thinc-8.0.1-cp36-cp36m-manylinux2014_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 47.4MB/s
# Requirement already satisfied, skipping upgrade: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied, skipping upgrade: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.5)
# Requirement already satisfied, skipping upgrade: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.19.5)
# Requirement already satisfied, skipping upgrade: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.23.0)
# Collecting srsly<3.0.0,>=2.4.0
#   Downloading https://files.pythonhosted.org/packages/4c/b7/2a8da28c6b4db5137d6ba949f0160d4628582b1fef5665ead8bb96ac9346/srsly-2.4.0-cp36-cp36m-manylinux2014_x86_64.whl (456kB)
#      |████████████████████████████████| 460kB 43.5MB/s
# Requirement already satisfied, skipping upgrade: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (4.41.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy) (53.0.0)
# Collecting catalogue<2.1.0,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/48/5c/493a2f3bb0eac17b1d48129ecfd251f0520b6c89493e9fd0522f534a9e4a/catalogue-2.0.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied, skipping upgrade: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.6/dist-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Collecting smart-open<4.0.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/11/9a/ba2d5f67f25e8d5bbf2fcec7a99b1e38428e83cb715f64dd179ca43a11bb/smart_open-3.0.0.tar.gz (113kB)
#      |████████████████████████████████| 122kB 36.6MB/s
# Requirement already satisfied, skipping upgrade: dataclasses<1.0,>=0.6; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from pathy->spacy) (0.8)
# Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->spacy) (1.1.1)
# Collecting contextvars<3,>=2.4; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy) (3.4.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 10.9MB/s
# Building wheels for collected packages: smart-open, contextvars
#   Building wheel for smart-open (setup.py) ... done
#   Created wheel for smart-open: filename=smart_open-3.0.0-cp36-none-any.whl size=107097 sha256=2f3937362f00cf8d8a55ac58639828473c30772a0a78b90ca1c1f8c938d9c61e
#   Stored in directory: /root/.cache/pip/wheels/18/88/7c/f06dabd5e9cabe02d2269167bcacbbf9b47d0c0ff7d6ebcb78
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7667 sha256=0b9aae4b47b47dc612fe1717c8af5ccc7d0fac60689b18e532cf18793805f4d8
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built smart-open contextvars
# Installing collected packages: typer, smart-open, pathy, spacy-legacy, pydantic, immutables, contextvars, catalogue, srsly, thinc, spacy
#   Found existing installation: smart-open 4.1.2
#     Uninstalling smart-open-4.1.2:
#       Successfully uninstalled smart-open-4.1.2
#   Found existing installation: catalogue 1.0.0
#     Uninstalling catalogue-1.0.0:
#       Successfully uninstalled catalogue-1.0.0
#   Found existing installation: srsly 1.0.5
#     Uninstalling srsly-1.0.5:
#       Successfully uninstalled srsly-1.0.5
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed catalogue-2.0.1 contextvars-2.4 immutables-0.14 pathy-0.3.5 pydantic-1.7.3 smart-open-3.0.0 spacy-3.0.1 spacy-legacy-3.0.1 srsly-2.4.0 thinc-8.0.1 typer-0.3.2
# 2021-02-09 16:23:26.574298: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# Collecting pl-core-news-md==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/pl_core_news_md-3.0.0/pl_core_news_md-3.0.0-py3-none-any.whl (88.4MB)
#      |████████████████████████████████| 88.4MB 43kB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from pl-core-news-md==3.0.0) (3.0.1)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.4.0)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (1.7.3)
# Requirement already satisfied: thinc<8.1.0,>=8.0.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (8.0.1)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (0.3.2)
# Requirement already satisfied: pathy in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (0.3.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (1.19.5)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.0.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (4.41.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (53.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.11.3)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.0.5)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (0.4.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (20.9)
# Requirement already satisfied: typing-extensions>=3.7.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.7.4.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.4.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.0.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (0.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.4.0)
# Requirement already satisfied: dataclasses>=0.6; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from pydantic<1.8.0,>=1.7.1->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (0.8)
# Requirement already satisfied: contextvars<3,>=2.4; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from thinc<8.1.0,>=8.0.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.4)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.6/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (7.1.2)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from pathy->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (1.1.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (2.4.7)
# Requirement already satisfied: immutables>=0.9 in /usr/local/lib/python3.6/dist-packages (from contextvars<3,>=2.4; python_version < "3.7"->thinc<8.1.0,>=8.0.0->spacy<3.1.0,>=3.0.0->pl-core-news-md==3.0.0) (0.14)
# Installing collected packages: pl-core-news-md
# Successfully installed pl-core-news-md-3.0.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('pl_core_news_md')
# <module 'pkg_resources' from '/usr/local/lib/python3.6/dist-packages/pkg_resources/__init__.py'>

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

basedir ='/content/drive/MyDrive/MB/'
# Out:
# Mounted at /content/drive

# %%
translated_descriptions = pickle.load(open('/content/drive/MyDrive/Translations/translated_descriptions.pkl', 'rb'))
print('Loaded %d translated descriptions' % len(translated_descriptions))
# Out:
# Loaded 8092 translated descriptions

# %%
import spacy
nlp = spacy.load('pl_core_news_md')

# %%
def preprocess_description(nlp, description):
  result = []
  for token in nlp(description):
    if token.is_stop or token.is_punct or token.like_num or not token.is_alpha:
      continue
    result.append(token.lemma_.lower())
  return ' '.join(result)

# %%
import spacy
nlp = spacy.load('pl_core_news_md')

clean_translated_descriptions = {}
for image_id, image_descriptions in tqdm(translated_descriptions.items()):
  for description in image_descriptions:
    clean_description = preprocess_description(nlp, description)
    
    if image_id not in clean_translated_descriptions:
      clean_translated_descriptions[image_id] = list()
    clean_translated_descriptions[image_id].append(clean_description)
print(len(clean_translated_descriptions))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=8092.0), HTML(value='')))
# 8092

# %%
with open(basedir + 'PL_clean_translated_descriptions.pkl', 'wb') as clean_translations_pickle:
  pickle.dump(clean_translated_descriptions, clean_translations_pickle)
